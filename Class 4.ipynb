# %%
# mylist = []
# mylist = list()

help([])

# %%
class SinglyLinkedList:
    class Node:
        def __init__(self, data)
        self.data = data
        self.next = None
        
    def __init__(self):
        self.head = None
        
    def append(self, value):
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            
    def __str__(self):
        # must return a string
        out = "["
        curren = self.head
        while current:
            out += "%s" % current.data
            current = current.next
        out += "]"    
        return out

    def index(self, value):
        if self.head:
            counter = 0
            current = self.head
            while current and current.data != value:
                current = current.next
                counter += 1
            if current.data == value:
                return counter
        raise ValueError("Value not found")
            
        # return the position of value in the list if it exist; ValueError otherwise
        pass
            
        
    def insert(self, index, value)
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            if index == 0:
                old_head = self.head
                self.head = new_node
                new_node.next = old_head
            else:
                current = self.head
                prev = None
                counter = 0
                while current.next and index != counter:
                    prev = current
                    current = current.next
                    counter += 1
                if index == counter:
                    prev.next = new_node
                    new_node.next = current
                else:
                    current.next = new_node
        # insert value BEFORE index
        pass
    
    def remove(self, value)
        # remove the first occurence value (and node)
        # raise ValueError if not present
        pass

# %%
mystring = "Hello world"
ourlist = SinglyLinkedList()
pythonlist = []

print("Empty lists:")
print("Our list: %s" % pythonlist)
      
ourlist.append("H")
pythonlist.append("H")
print("Lists with single element:")
print("Our list:" %s" % ourlist)
print("Python list: %s" % pythonlist)
      
for letter in mystring:
      ourlist.append(letter)

# %%
print("What we have:")
x = SinglyLinkedList()

for number is range(1, 5):
    x.append(number)
    
print(x)

print("What python3 has:")
mylist = []

# empty list

print(mylist)

# one element:
mylist.append(1)

print(mylist)

# more than one element:
mylist.append(2)
mylist.append(3)

print(mylist)


# mini challenge
# Make our SinglyLinkedList class print exactly like python lists, considering the example above.

def __str__(self):
    out = "["
    current = self.head
    if current:
        out += "%s" % cuurent.data
        current = current.next
        while current:
            out += ", %s" current.data
            current = current.next
    out += "["
    return out

# %%
class DoublyLinkedList:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            self.prev = None
            
    def __init__(self):
        self.head = None
        
    def append(self, value):
        new_node = self.Node(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next
